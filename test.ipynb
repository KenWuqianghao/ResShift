# %%
for i in range (1, 1255):
    str = "/content/ResShift/high_res/{}.jpg".format(i)
    print(str)
# Out:
# /content/ResShift/high_res/1.jpg
# /content/ResShift/high_res/2.jpg
# /content/ResShift/high_res/3.jpg
# /content/ResShift/high_res/4.jpg
# /content/ResShift/high_res/5.jpg
# /content/ResShift/high_res/6.jpg
# /content/ResShift/high_res/7.jpg
# /content/ResShift/high_res/8.jpg
# /content/ResShift/high_res/9.jpg
# /content/ResShift/high_res/10.jpg
# /content/ResShift/high_res/11.jpg
# /content/ResShift/high_res/12.jpg
# /content/ResShift/high_res/13.jpg
# /content/ResShift/high_res/14.jpg
# /content/ResShift/high_res/15.jpg
# /content/ResShift/high_res/16.jpg
# /content/ResShift/high_res/17.jpg
# /content/ResShift/high_res/18.jpg
# /content/ResShift/high_res/19.jpg
# /content/ResShift/high_res/20.jpg
# /content/ResShift/high_res/21.jpg
# /content/ResShift/high_res/22.jpg
# /content/ResShift/high_res/23.jpg
# /content/ResShift/high_res/24.jpg
# /content/ResShift/high_res/25.jpg
# /content/ResShift/high_res/26.jpg
# /content/ResShift/high_res/27.jpg
# /content/ResShift/high_res/28.jpg
# ...
